# %% [markdown]
# # Linear Regression

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import IPython.display

# %%
dt = pd.read_csv("./clean_data/clean_data.csv")

# %%
area_vars = ['SquareFootAreaoftheLot', 'SquareFootAreaofFinishedBasement', 'SquareFootAreaofHouse']
price_vars = ['SalesPrice', 'ContractPrice']

# %%
# The following loop will create an OLS model for each x and y
for x in area_vars:
    for y in price_vars:
        IPython.display.display_html(f"<h2>LM model for <b>{y}</b> vs <b>{x}</b>:</h2>", raw=True)
        lm_data = dt[[x, y]].dropna() # Drop the na in this combination only
        lm = sm.OLS(
            endog=lm_data[y], 
            exog=sm.add_constant(lm_data[x])
        ).fit()
        IPython.display.display(lm.summary())
# Out:
# <h2>LM model for <b>SalesPrice</b> vs <b>SquareFootAreaoftheLot</b>:</h2>
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             SalesPrice   R-squared:                       0.067
# Model:                            OLS   Adj. R-squared:                  0.066
# Method:                 Least Squares   F-statistic:                     1229.
# Date:                Wed, 08 Apr 2020   Prob (F-statistic):          3.55e-260
# Time:                        22:07:10   Log-Likelihood:            -2.2584e+05
# No. Observations:               17247   AIC:                         4.517e+05
# Df Residuals:                   17245   BIC:                         4.517e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   1.811e+05   1177.080    153.825      0.000    1.79e+05    1.83e+05
# SquareFootAreaoftheLot     1.8526      0.053     35.059      0.000       1.749       1.956
# ==============================================================================
# Omnibus:                     6624.827   Durbin-Watson:                   1.664
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            28289.256
# Skew:                           1.874   Prob(JB):                         0.00
# Kurtosis:                       8.032   Cond. No.                     2.93e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.93e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
# <h2>LM model for <b>ContractPrice</b> vs <b>SquareFootAreaoftheLot</b>:</h2>
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          ContractPrice   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     6.979
# Date:                Wed, 08 Apr 2020   Prob (F-statistic):            0.00828
# Time:                        22:07:10   Log-Likelihood:                -58846.
# No. Observations:                4414   AIC:                         1.177e+05
# Df Residuals:                    4412   BIC:                         1.177e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   1.911e+05   2767.430     69.062      0.000    1.86e+05    1.97e+05
# SquareFootAreaoftheLot     0.0499      0.019      2.642      0.008       0.013       0.087
# ==============================================================================
# Omnibus:                     3338.744   Durbin-Watson:                   1.770
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            79521.079
# Skew:                           3.419   Prob(JB):                         0.00
# Kurtosis:                      22.637   Cond. No.                     1.80e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.8e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
# <h2>LM model for <b>SalesPrice</b> vs <b>SquareFootAreaofFinishedBasement</b>:</h2>
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             SalesPrice   R-squared:                       0.095
# Model:                            OLS   Adj. R-squared:                  0.095
# Method:                 Least Squares   F-statistic:                     119.0
# Date:                Wed, 08 Apr 2020   Prob (F-statistic):           2.03e-26
# Time:                        22:07:10   Log-Likelihood:                -14804.
# No. Observations:                1130   AIC:                         2.961e+04
# Df Residuals:                    1128   BIC:                         2.962e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                             1.732e+05   7360.289     23.535      0.000    1.59e+05    1.88e+05
# SquareFootAreaofFinishedBasement    91.0105      8.341     10.911      0.000      74.644     107.377
# ==============================================================================
# Omnibus:                      314.166   Durbin-Watson:                   1.548
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              818.898
# Skew:                           1.450   Prob(JB):                    1.51e-178
# Kurtosis:                       5.997   Cond. No.                     1.84e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.84e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
# <h2>LM model for <b>ContractPrice</b> vs <b>SquareFootAreaofFinishedBasement</b>:</h2>
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          ContractPrice   R-squared:                       0.036
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     14.39
# Date:                Wed, 08 Apr 2020   Prob (F-statistic):           0.000173
# Time:                        22:07:10   Log-Likelihood:                -5031.5
# No. Observations:                 382   AIC:                         1.007e+04
# Df Residuals:                     380   BIC:                         1.007e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                             2.011e+05   1.48e+04     13.554      0.000    1.72e+05     2.3e+05
# SquareFootAreaofFinishedBasement    48.9704     12.911      3.793      0.000      23.584      74.357
# ==============================================================================
# Omnibus:                       92.751   Durbin-Watson:                   1.486
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              182.400
# Skew:                           1.303   Prob(JB):                     2.47e-40
# Kurtosis:                       5.161   Cond. No.                     2.62e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.62e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
# <h2>LM model for <b>SalesPrice</b> vs <b>SquareFootAreaofHouse</b>:</h2>
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             SalesPrice   R-squared:                       0.519
# Model:                            OLS   Adj. R-squared:                  0.519
# Method:                 Least Squares   F-statistic:                 2.001e+04
# Date:                Wed, 08 Apr 2020   Prob (F-statistic):               0.00
# Time:                        22:07:10   Log-Likelihood:            -2.3609e+05
# No. Observations:               18518   AIC:                         4.722e+05
# Df Residuals:                   18516   BIC:                         4.722e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                 -1.672e+04   1691.973     -9.884      0.000      -2e+04   -1.34e+04
# SquareFootAreaofHouse    97.5020      0.689    141.456      0.000      96.151      98.853
# ==============================================================================
# Omnibus:                     6636.688   Durbin-Watson:                   1.507
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            39243.290
# Skew:                           1.607   Prob(JB):                         0.00
# Kurtosis:                       9.366   Cond. No.                     6.78e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.78e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
# <h2>LM model for <b>ContractPrice</b> vs <b>SquareFootAreaofHouse</b>:</h2>
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          ContractPrice   R-squared:                       0.557
# Model:                            OLS   Adj. R-squared:                  0.557
# Method:                 Least Squares   F-statistic:                     5947.
# Date:                Wed, 08 Apr 2020   Prob (F-statistic):               0.00
# Time:                        22:07:10   Log-Likelihood:                -61112.
# No. Observations:                4725   AIC:                         1.222e+05
# Df Residuals:                    4723   BIC:                         1.222e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                 -5.458e+04   3559.079    -15.334      0.000   -6.16e+04   -4.76e+04
# SquareFootAreaofHouse    97.4521      1.264     77.116      0.000      94.975      99.930
# ==============================================================================
# Omnibus:                     3614.062   Durbin-Watson:                   1.780
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           144124.433
# Skew:                           3.272   Prob(JB):                         0.00
# Kurtosis:                      29.254   Cond. No.                     6.88e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.88e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
