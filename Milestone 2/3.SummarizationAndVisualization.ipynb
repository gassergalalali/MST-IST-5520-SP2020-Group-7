# %% [markdown]
# <h1 align="center"> Data Summarization and Visualization </h1>

# %% [markdown]
# Note: Use the "cleanedDataPriceDr" data in `./clean_data/` after running `./2.Cleaning.ipynb`

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
dt = pd.read_csv("./clean_data/cleanedDataPriceDr.csv")

# %%
dt.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  CentralAir-conditioning  Foundation  Condominium  \
# 0           0             0                      1.0         1.0          2.0
# 1           1             1                      2.0         1.0          2.0
# 2           3             3                      2.0         1.0          2.0
# 3           4             4                      1.0         1.0          2.0
# 4           5             6                      2.0         1.0          2.0
#
#    Deck  DesignofHouse  Division  TypeofFinancing  FinishedBasement  ...  \
# 0   1.0            1.0         1              1.0               2.0  ...
# 1   1.0            1.0         1              4.0               1.0  ...
# 2   2.0            1.0         1              1.0               2.0  ...
# 3   1.0            1.0         1              1.0               2.0  ...
# 4   2.0            1.0         1              1.0               2.0  ...
#
#    FullBathrooms  HalfBathrooms  SaleDate  Weight  PrimarySpaceHeatingFuel  \
# 0            2.0            1.0    199904      53                      3.0
# 1            2.0            0.0    199904      39                      1.0
# 2            2.0            1.0    199903      58                      2.0
# 3            2.0            1.0    199907      40                      2.0
# 4            1.0            0.0    199812      31                      3.0
#
#    SalesPrice  SquareFootAreaofHouse  LotValue  \
# 0    249900.0                 2400.0   80000.0
# 1    139900.0                 1192.0   30000.0
# 2    271900.0                 2376.0   90000.0
# 3    320000.0                 2600.0   90000.0
# 4    163000.0                 1120.0   63700.0
#
#    SquareFootAreaofFinishedBasement  SquareFootAreaoftheLot
# 0                               0.0                 52272.0
# 1                             596.0                  9000.0
# 2                               0.0                 40075.0
# 3                               0.0                 40075.0
# 4                               0.0                 87120.0
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Data Description

# %%
dt.describe().T
# Out:
#                                      count           mean            std  \
# Unnamed: 0                        158470.0  121213.730744   77309.849449
# Unnamed: 0.1                      158470.0   15472.524068    9157.910192
# CentralAir-conditioning           158470.0       1.088029       0.283338
# Foundation                        158470.0       2.225803       0.920469
# Condominium                       158470.0       1.974620       0.157277
# Deck                              158470.0       1.753051       0.431238
# DesignofHouse                     158470.0       1.063772       0.244348
# Division                          158470.0       5.642040       2.132366
# TypeofFinancing                   158470.0       1.386729       0.879146
# FinishedBasement                  158470.0       0.598176       0.880372
# ParkingFacility                   158470.0       2.254181       0.605396
# PrimarySpaceHeatingSystem         158470.0       1.736726       0.518827
# MetropolitanArea                  158470.0       1.075440       0.264101
# ConstructionMethod                158470.0       2.963936       0.226766
# Patio                             158470.0       1.477661       0.499502
# Porch                             158470.0       1.455266       0.497996
# Stories                           158470.0       1.571566       0.494853
# PrimaryExteriorWallMaterial       158470.0       3.487316       1.602356
# SecondaryExteriorWallMaterial     158470.0       2.231508       2.889350
# SecondaryExteriorWallMaterial.1   158470.0       1.512842       0.499837
# Bedrooms                          158470.0       3.484817       0.731325
# Fireplace                         158470.0       0.635464       0.557785
# FullBathrooms                     158470.0       2.288282       0.588657
# HalfBathrooms                     158470.0       0.514924       0.527567
# SaleDate                          158470.0  200566.934587     550.864219
# Weight                            158470.0      67.829513      46.837531
# PrimarySpaceHeatingFuel           158470.0       1.709850       0.508359
# SalesPrice                        158470.0  266220.491500  155000.860575
# SquareFootAreaofHouse             158470.0    2462.483637     898.930266
# LotValue                          158470.0   54137.598915   43279.830994
# SquareFootAreaofFinishedBasement  158470.0      59.587108     256.790112
# SquareFootAreaoftheLot            158470.0   14517.244532   16739.615705
#
#                                        min       25%       50%        75%  \
# Unnamed: 0                             0.0   54278.5  113444.5  181783.75
# Unnamed: 0.1                           0.0    8219.0   14436.0   23110.00
# CentralAir-conditioning                1.0       1.0       1.0       1.00
# Foundation                             1.0       1.0       3.0       3.00
# Condominium                            1.0       2.0       2.0       2.00
# Deck                                   1.0       2.0       2.0       2.00
# DesignofHouse                          1.0       1.0       1.0       1.00
# Division                               1.0       4.0       5.0       7.00
# TypeofFinancing                        1.0       1.0       1.0       1.00
# FinishedBasement                       0.0       0.0       0.0       2.00
# ParkingFacility                        1.0       2.0       2.0       3.00
# PrimarySpaceHeatingSystem              1.0       1.0       2.0       2.00
# MetropolitanArea                       1.0       1.0       1.0       1.00
# ConstructionMethod                     1.0       3.0       3.0       3.00
# Patio                                  1.0       1.0       1.0       2.00
# Porch                                  1.0       1.0       1.0       2.00
# Stories                                1.0       1.0       2.0       2.00
# PrimaryExteriorWallMaterial            1.0       2.0       3.0       4.00
# SecondaryExteriorWallMaterial          0.0       0.0       0.0       4.00
# SecondaryExteriorWallMaterial.1        1.0       1.0       2.0       2.00
# Bedrooms                               2.0       3.0       3.0       4.00
# Fireplace                              0.0       0.0       1.0       1.00
# FullBathrooms                          1.0       2.0       2.0       3.00
# HalfBathrooms                          0.0       0.0       1.0       1.00
# SaleDate                          199603.0  200109.0  200409.0  200907.00
# Weight                                 1.0      36.0      52.0      90.00
# PrimarySpaceHeatingFuel                1.0       1.0       2.0       2.00
# SalesPrice                         48000.0  158900.0  225000.0  329000.00
# SquareFootAreaofHouse                784.0    1795.0    2300.0    2979.00
# LotValue                            4800.0   28000.0   40000.0   66375.00
# SquareFootAreaofFinishedBasement       0.0       0.0       0.0       0.00
# SquareFootAreaoftheLot              2000.0    6300.0    9000.0   14000.00
#
#                                         max
# Unnamed: 0                         279610.0
# Unnamed: 0.1                        36419.0
# CentralAir-conditioning                 2.0
# Foundation                              4.0
# Condominium                             2.0
# Deck                                    2.0
# DesignofHouse                           2.0
# Division                                9.0
# TypeofFinancing                         5.0
# FinishedBasement                        2.0
# ParkingFacility                         4.0
# PrimarySpaceHeatingSystem               4.0
# MetropolitanArea                        2.0
# ConstructionMethod                      3.0
# Patio                                   2.0
# Porch                                   2.0
# Stories                                 2.0
# PrimaryExteriorWallMaterial             8.0
# SecondaryExteriorWallMaterial           9.0
# SecondaryExteriorWallMaterial.1         2.0
# Bedrooms                                5.0
# Fireplace                               2.0
# FullBathrooms                           4.0
# HalfBathrooms                           2.0
# SaleDate                           201904.0
# Weight                                613.0
# PrimarySpaceHeatingFuel                 4.0
# SalesPrice                        2150000.0
# SquareFootAreaofHouse                8240.0
# LotValue                           723000.0
# SquareFootAreaofFinishedBasement     3643.0
# SquareFootAreaoftheLot              87120.0

# %% [markdown]
# ## Correlation

# %%
dt.corr()
# Out:
#                                   Unnamed: 0  Unnamed: 0.1  \
# Unnamed: 0                          1.000000     -0.286476
# Unnamed: 0.1                       -0.286476      1.000000
# CentralAir-conditioning            -0.113074      0.193540
# Foundation                          0.020210      0.424135
# Condominium                         0.120411      0.011083
# Deck                                0.048771      0.191128
# DesignofHouse                      -0.042524     -0.072521
# Division                            0.034017      0.892299
# TypeofFinancing                     0.089379     -0.017479
# FinishedBasement                   -0.049239     -0.428828
# ParkingFacility                     0.035204      0.035336
# PrimarySpaceHeatingSystem          -0.146671      0.061882
# MetropolitanArea                   -0.076131      0.036662
# ConstructionMethod                  0.033433      0.069553
# Patio                              -0.109648     -0.145684
# Porch                              -0.147733     -0.020668
# Stories                             0.020853     -0.118483
# PrimaryExteriorWallMaterial         0.089714     -0.140070
# SecondaryExteriorWallMaterial       0.238009     -0.056785
# SecondaryExteriorWallMaterial.1    -0.139915      0.122572
# Bedrooms                            0.096515      0.030019
# Fireplace                          -0.048901      0.031768
# FullBathrooms                       0.170229      0.024963
# HalfBathrooms                       0.019000     -0.161908
# SaleDate                            0.977727     -0.349602
# Weight                             -0.033836      0.172845
# PrimarySpaceHeatingFuel            -0.111314      0.017497
# SalesPrice                          0.296355     -0.070355
# SquareFootAreaofHouse               0.167504     -0.082079
# LotValue                            0.161484     -0.041163
# SquareFootAreaofFinishedBasement    0.084773     -0.117794
# SquareFootAreaoftheLot              0.003151     -0.220673
#
#                                   CentralAir-conditioning  Foundation  \
# Unnamed: 0                                      -0.113074    0.020210
# Unnamed: 0.1                                     0.193540    0.424135
# CentralAir-conditioning                          1.000000   -0.174814
# Foundation                                      -0.174814    1.000000
# Condominium                                     -0.026048   -0.000123
# Deck                                            -0.039564    0.393329
# DesignofHouse                                   -0.011086    0.014647
# Division                                         0.176278    0.463536
# TypeofFinancing                                 -0.012891    0.098806
# FinishedBasement                                 0.120075   -0.904851
# ParkingFacility                                 -0.013789   -0.088049
# PrimarySpaceHeatingSystem                        0.264972   -0.280371
# MetropolitanArea                                 0.029061   -0.103352
# ConstructionMethod                              -0.038884    0.064378
# Patio                                            0.075336   -0.346679
# Porch                                            0.009259    0.034708
# Stories                                          0.088332   -0.199209
# PrimaryExteriorWallMaterial                      0.049939   -0.148461
# SecondaryExteriorWallMaterial                   -0.066996   -0.041485
# SecondaryExteriorWallMaterial.1                  0.063533    0.135292
# Bedrooms                                        -0.051168    0.007910
# Fireplace                                        0.024447   -0.176260
# FullBathrooms                                   -0.103157    0.048395
# HalfBathrooms                                    0.057701   -0.257732
# SaleDate                                        -0.112201   -0.012684
# Weight                                           0.001203    0.130275
# PrimarySpaceHeatingFuel                          0.229112   -0.332864
# SalesPrice                                       0.027688   -0.178501
# SquareFootAreaofHouse                           -0.113968   -0.078993
# LotValue                                         0.079401   -0.181337
# SquareFootAreaofFinishedBasement                -0.006477   -0.309021
# SquareFootAreaoftheLot                          -0.012233   -0.249049
#
#                                   Condominium      Deck  DesignofHouse  \
# Unnamed: 0                           0.120411  0.048771      -0.042524
# Unnamed: 0.1                         0.011083  0.191128      -0.072521
# CentralAir-conditioning             -0.026048 -0.039564      -0.011086
# Foundation                          -0.000123  0.393329       0.014647
# Condominium                          1.000000  0.007515      -0.309770
# Deck                                 0.007515  1.000000      -0.038587
# DesignofHouse                       -0.309770 -0.038587       1.000000
# Division                             0.049454  0.237670      -0.087702
# TypeofFinancing                      0.014989  0.066067      -0.000860
# FinishedBasement                    -0.009850 -0.300734      -0.015464
# ParkingFacility                      0.041509 -0.041258      -0.087440
# PrimarySpaceHeatingSystem           -0.022263 -0.105624      -0.003900
# MetropolitanArea                    -0.038828 -0.103486       0.016780
# ConstructionMethod                   0.006007  0.024824      -0.033202
# Patio                               -0.010109 -0.295217       0.003141
# Porch                               -0.054135  0.035595       0.105225
# Stories                             -0.010635 -0.156528       0.074929
# PrimaryExteriorWallMaterial         -0.010742 -0.062897       0.055946
# SecondaryExteriorWallMaterial        0.033107  0.018895      -0.008354
# SecondaryExteriorWallMaterial.1     -0.015761  0.006515      -0.022464
# Bedrooms                             0.131448 -0.028196      -0.262432
# Fireplace                            0.027610 -0.145857      -0.097924
# FullBathrooms                        0.061921 -0.054425      -0.105528
# HalfBathrooms                       -0.023042 -0.145203       0.067073
# SaleDate                             0.114131  0.031340      -0.038913
# Weight                               0.012264  0.052781       0.006889
# PrimarySpaceHeatingFuel             -0.016731 -0.133670      -0.018631
# SalesPrice                           0.032554 -0.141021      -0.073696
# SquareFootAreaofHouse                0.077921 -0.087530      -0.158951
# LotValue                             0.018147 -0.139980      -0.060476
# SquareFootAreaofFinishedBasement     0.007072 -0.164081       0.018325
# SquareFootAreaoftheLot               0.071775 -0.217404      -0.156129
#
#                                   Division  TypeofFinancing  FinishedBasement  \
# Unnamed: 0                        0.034017         0.089379         -0.049239
# Unnamed: 0.1                      0.892299        -0.017479         -0.428828
# CentralAir-conditioning           0.176278        -0.012891          0.120075
# Foundation                        0.463536         0.098806         -0.904851
# Condominium                       0.049454         0.014989         -0.009850
# Deck                              0.237670         0.066067         -0.300734
# DesignofHouse                    -0.087702        -0.000860         -0.015464
# Division                          1.000000         0.039265         -0.475767
# TypeofFinancing                   0.039265         1.000000         -0.103425
# FinishedBasement                 -0.475767        -0.103425          1.000000
# ParkingFacility                   0.041612        -0.041622          0.074988
# PrimarySpaceHeatingSystem         0.015215        -0.062980          0.296087
# MetropolitanArea                 -0.070522         0.033828          0.020052
# ConstructionMethod                0.092581        -0.008130         -0.054571
# Patio                            -0.210750        -0.069615          0.307005
# Porch                            -0.074968        -0.006933          0.008348
# Stories                          -0.115145        -0.139762          0.193192
# PrimaryExteriorWallMaterial      -0.118976        -0.019097          0.106080
# SecondaryExteriorWallMaterial     0.044930         0.023762          0.050508
# SecondaryExteriorWallMaterial.1   0.055123        -0.014999         -0.146570
# Bedrooms                          0.069142        -0.117258         -0.013685
# Fireplace                         0.019510        -0.091449          0.160278
# FullBathrooms                     0.088807        -0.076824         -0.079563
# HalfBathrooms                    -0.161957        -0.119703          0.240236
# SaleDate                         -0.026993         0.103112         -0.016862
# Weight                            0.112748         0.005683         -0.151023
# PrimarySpaceHeatingFuel          -0.015543        -0.112438          0.345001
# SalesPrice                       -0.001553        -0.148139          0.155513
# SquareFootAreaofHouse            -0.029976        -0.141417          0.041088
# LotValue                         -0.011533        -0.132481          0.161695
# SquareFootAreaofFinishedBasement -0.095215        -0.004300          0.105912
# SquareFootAreaoftheLot           -0.264337        -0.048588          0.208051
#
#                                   ...  FullBathrooms  HalfBathrooms  SaleDate  \
# Unnamed: 0                        ...       0.170229       0.019000  0.977727
# Unnamed: 0.1                      ...       0.024963      -0.161908 -0.349602
# CentralAir-conditioning           ...      -0.103157       0.057701 -0.112201
# Foundation                        ...       0.048395      -0.257732 -0.012684
# Condominium                       ...       0.061921      -0.023042  0.114131
# Deck                              ...      -0.054425      -0.145203  0.031340
# DesignofHouse                     ...      -0.105528       0.067073 -0.038913
# Division                          ...       0.088807      -0.161957 -0.026993
# TypeofFinancing                   ...      -0.076824      -0.119703  0.103112
# FinishedBasement                  ...      -0.079563       0.240236 -0.016862
# ParkingFacility                   ...       0.185963       0.014282  0.031531
# PrimarySpaceHeatingSystem         ...      -0.022575       0.150065 -0.143779
# MetropolitanArea                  ...      -0.091264      -0.096556 -0.070527
# ConstructionMethod                ...       0.041153      -0.013092  0.027344
# Patio                             ...      -0.064738       0.119441 -0.097248
# Porch                             ...      -0.066266       0.003154 -0.147443
# Stories                           ...       0.243158       0.554594  0.024423
# PrimaryExteriorWallMaterial       ...      -0.026865       0.089384  0.094997
# SecondaryExteriorWallMaterial     ...       0.129777       0.068468  0.237927
# SecondaryExteriorWallMaterial.1   ...      -0.084386      -0.084328 -0.146828
# Bedrooms                          ...       0.554063       0.197248  0.087564
# Fireplace                         ...       0.234978       0.197955 -0.045448
# FullBathrooms                     ...       1.000000      -0.029418  0.158097
# HalfBathrooms                     ...      -0.029418       1.000000  0.024553
# SaleDate                          ...       0.158097       0.024553  1.000000
# Weight                            ...      -0.036204      -0.082392 -0.059936
# PrimarySpaceHeatingFuel           ...       0.029590       0.194968 -0.104582
# SalesPrice                        ...       0.488669       0.291577  0.276524
# SquareFootAreaofHouse             ...       0.616948       0.317094  0.154304
# LotValue                          ...       0.341591       0.257296  0.139681
# SquareFootAreaofFinishedBasement  ...       0.183533       0.056243  0.093792
# SquareFootAreaoftheLot            ...       0.104659       0.086165  0.013445
#
#                                     Weight  PrimarySpaceHeatingFuel  \
# Unnamed: 0                       -0.033836                -0.111314
# Unnamed: 0.1                      0.172845                 0.017497
# CentralAir-conditioning           0.001203                 0.229112
# Foundation                        0.130275                -0.332864
# Condominium                       0.012264                -0.016731
# Deck                              0.052781                -0.133670
# DesignofHouse                     0.006889                -0.018631
# Division                          0.112748                -0.015543
# TypeofFinancing                   0.005683                -0.112438
# FinishedBasement                 -0.151023                 0.345001
# ParkingFacility                  -0.032138                 0.066869
# PrimarySpaceHeatingSystem        -0.076397                 0.775109
# MetropolitanArea                  0.095655                -0.045886
# ConstructionMethod                0.018517                -0.026177
# Patio                            -0.043318                 0.168960
# Porch                             0.068383                 0.008678
# Stories                          -0.065359                 0.222290
# PrimaryExteriorWallMaterial      -0.006319                 0.032132
# SecondaryExteriorWallMaterial    -0.054912                 0.027971
# SecondaryExteriorWallMaterial.1   0.062494                -0.043077
# Bedrooms                         -0.034358                 0.074173
# Fireplace                        -0.095468                 0.255474
# FullBathrooms                    -0.036204                 0.029590
# HalfBathrooms                    -0.082392                 0.194968
# SaleDate                         -0.059936                -0.104582
# Weight                            1.000000                -0.078165
# PrimarySpaceHeatingFuel          -0.078165                 1.000000
# SalesPrice                       -0.130329                 0.221693
# SquareFootAreaofHouse            -0.092231                 0.095120
# LotValue                         -0.123047                 0.255396
# SquareFootAreaofFinishedBasement -0.027279                 0.084799
# SquareFootAreaoftheLot           -0.073397                 0.033453
#
#                                   SalesPrice  SquareFootAreaofHouse  LotValue  \
# Unnamed: 0                          0.296355               0.167504  0.161484
# Unnamed: 0.1                       -0.070355              -0.082079 -0.041163
# CentralAir-conditioning             0.027688              -0.113968  0.079401
# Foundation                         -0.178501              -0.078993 -0.181337
# Condominium                         0.032554               0.077921  0.018147
# Deck                               -0.141021              -0.087530 -0.139980
# DesignofHouse                      -0.073696              -0.158951 -0.060476
# Division                           -0.001553              -0.029976 -0.011533
# TypeofFinancing                    -0.148139              -0.141417 -0.132481
# FinishedBasement                    0.155513               0.041088  0.161695
# ParkingFacility                     0.197150               0.204484  0.144984
# PrimarySpaceHeatingSystem           0.149088               0.026134  0.188524
# MetropolitanArea                   -0.128245              -0.137368 -0.113948
# ConstructionMethod                  0.027008               0.035034  0.007793
# Patio                               0.087771              -0.016205  0.127906
# Porch                              -0.044355              -0.050643 -0.016662
# Stories                             0.327194               0.384439  0.284399
# PrimaryExteriorWallMaterial         0.058694              -0.019786  0.071650
# SecondaryExteriorWallMaterial       0.113217               0.178626  0.049764
# SecondaryExteriorWallMaterial.1    -0.064228              -0.135375 -0.014300
# Bedrooms                            0.399147               0.603338  0.299425
# Fireplace                           0.302430               0.348685  0.249592
# FullBathrooms                       0.488669               0.616948  0.341591
# HalfBathrooms                       0.291577               0.317094  0.257296
# SaleDate                            0.276524               0.154304  0.139681
# Weight                             -0.130329              -0.092231 -0.123047
# PrimarySpaceHeatingFuel             0.221693               0.095120  0.255396
# SalesPrice                          1.000000               0.659880  0.826229
# SquareFootAreaofHouse               0.659880               1.000000  0.488386
# LotValue                            0.826229               0.488386  1.000000
# SquareFootAreaofFinishedBasement    0.157759               0.271287  0.107453
# SquareFootAreaoftheLot              0.177765               0.218176  0.180352
#
#                                   SquareFootAreaofFinishedBasement  \
# Unnamed: 0                                                0.084773
# Unnamed: 0.1                                             -0.117794
# CentralAir-conditioning                                  -0.006477
# Foundation                                               -0.309021
# Condominium                                               0.007072
# Deck                                                     -0.164081
# DesignofHouse                                             0.018325
# Division                                                 -0.095215
# TypeofFinancing                                          -0.004300
# FinishedBasement                                          0.105912
# ParkingFacility                                           0.092650
# PrimarySpaceHeatingSystem                                 0.062207
# MetropolitanArea                                          0.024654
# ConstructionMethod                                       -0.015053
# Patio                                                     0.036594
# Porch                                                    -0.024164
# Stories                                                  -0.039689
# PrimaryExteriorWallMaterial                               0.062553
# SecondaryExteriorWallMaterial                             0.083464
# SecondaryExteriorWallMaterial.1                          -0.099751
# Bedrooms                                                  0.104701
# Fireplace                                                 0.126107
# FullBathrooms                                             0.183533
# HalfBathrooms                                             0.056243
# SaleDate                                                  0.093792
# Weight                                                   -0.027279
# PrimarySpaceHeatingFuel                                   0.084799
# SalesPrice                                                0.157759
# SquareFootAreaofHouse                                     0.271287
# LotValue                                                  0.107453
# SquareFootAreaofFinishedBasement                          1.000000
# SquareFootAreaoftheLot                                    0.063056
#
#                                   SquareFootAreaoftheLot
# Unnamed: 0                                      0.003151
# Unnamed: 0.1                                   -0.220673
# CentralAir-conditioning                        -0.012233
# Foundation                                     -0.249049
# Condominium                                     0.071775
# Deck                                           -0.217404
# DesignofHouse                                  -0.156129
# Division                                       -0.264337
# TypeofFinancing                                -0.048588
# FinishedBasement                                0.208051
# ParkingFacility                                 0.130022
# PrimarySpaceHeatingSystem                       0.007235
# MetropolitanArea                                0.131794
# ConstructionMethod                             -0.060560
# Patio                                           0.133832
# Porch                                          -0.103906
# Stories                                         0.035721
# PrimaryExteriorWallMaterial                    -0.007117
# SecondaryExteriorWallMaterial                  -0.016209
# SecondaryExteriorWallMaterial.1                 0.028885
# Bedrooms                                        0.094509
# Fireplace                                       0.162975
# FullBathrooms                                   0.104659
# HalfBathrooms                                   0.086165
# SaleDate                                        0.013445
# Weight                                         -0.073397
# PrimarySpaceHeatingFuel                         0.033453
# SalesPrice                                      0.177765
# SquareFootAreaofHouse                           0.218176
# LotValue                                        0.180352
# SquareFootAreaofFinishedBasement                0.063056
# SquareFootAreaoftheLot                          1.000000
#
# [32 rows x 32 columns]

# %%
#Heat Map Showing correlations among the varibales
corr = dt.corr()
f, ax = plt.subplots(figsize =(10, 10)) 
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr, cmap='YlGnBu', mask=mask, square=True, linewidths = 0.1)
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ## 1) Distribution for Sales Price

# %%
# Histogram + kernel density estimate
sns.distplot(dt['SalesPrice'])
plt.title('Histogram of SalesPrice')
plt.xlabel('Sales Price')
plt.figure(figsize=(20, 20))
plt.show()

# %% [markdown]
# Note: it is very clear that the "Sales price" data is skewed to the right

# %% [markdown]
# ## 2) Sales price vs Areas Variables

# %%
area_vars = ['SquareFootAreaoftheLot', 'SquareFootAreaofFinishedBasement', 'SquareFootAreaofHouse']
price_vars = ['SalesPrice']
plt.figure(figsize=(35, 10))
y_vars = price_vars
x_vars = area_vars
for y_i, y_var in enumerate(y_vars):
    for x_i, x_var in enumerate(x_vars):
        ax=plt.subplot(len(y_vars), len(x_vars), y_i * len(x_vars) + x_i + 1)
        ax.scatter(dt[x_var], dt[y_var], marker='x')
        plt.xlabel(x_var)
        plt.ylabel(y_var)
plt.show()

# %%
area_vars = ['SquareFootAreaoftheLot', 'SquareFootAreaofFinishedBasement', 'SquareFootAreaofHouse']

for y_i in area_vars:
        sns.jointplot(dt[y_i], dt['SalesPrice'], marker='x')
plt.show()

# %% [markdown]
# ## 3) Construction Method vs. Sales Price

# %%
df2 = dt[['ConstructionMethod','SalesPrice']]

df2.head()
# Out:
#    ConstructionMethod  SalesPrice
# 0                 3.0    249900.0
# 1                 1.0    139900.0
# 2                 3.0    271900.0
# 3                 3.0    320000.0
# 4                 3.0    163000.0

# %%
df2['ConstructionMethod'].unique()
# Out:
# array([3., 1., 2.])

# %%
import warnings
warnings.filterwarnings('ignore')

df2['ConstructionMethod'] = df2['ConstructionMethod'].replace(to_replace=1.0, value= 'Modular')
df2['ConstructionMethod'] = df2['ConstructionMethod'].replace(to_replace=2.0, value= 'Panelized/Precut')
df2['ConstructionMethod'] = df2['ConstructionMethod'].replace(to_replace=3.0, value= 'Site_built')

df2['ConstructionMethod'].value_counts()
# Out:
# Site_built          154075
# Panelized/Precut      3075
# Modular               1320
# Name: ConstructionMethod, dtype: int64

# %%
# Generate an aggregated DataFrame to represent the mean of Sales Price per Construction Method
mean_sales_price_by_ConstMethod = df2.groupby('ConstructionMethod').mean()

mean_sales_price_by_ConstMethod
# Out:
#                        SalesPrice
# ConstructionMethod
# Modular             201175.075758
# Panelized/Precut    273142.959350
# Site_built          266639.594925

# %%
ax = sns.barplot(x="ConstructionMethod", y="SalesPrice", data=df2, capsize=.2)
plt.title('Average Sales Price per Construction Method')
plt.ylabel('Sales Price ($)')
plt.show()

# %%
mean_sales_price_by_ConstMethod['SalesPrice'].plot(kind='pie',
                                                  colors=['darkorange','forestgreen','steelblue'],
                                                  autopct='%.1f',
                                                  fontsize=15,
                                                  figsize=(6,4),
                                                  explode=(0.05, 0.05, 0.05),
                                                  shadow=True)
plt.ylabel('')
plt.title('Average Sales Price per Construction Method ')
plt.show()

# %% [markdown]
# ## 4) Sale Year vs. Sales Price

# %%
dt['SaleYear']=dt['SaleDate']//100
dt.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  CentralAir-conditioning  Foundation  Condominium  \
# 0           0             0                      1.0         1.0          2.0
# 1           1             1                      2.0         1.0          2.0
# 2           3             3                      2.0         1.0          2.0
# 3           4             4                      1.0         1.0          2.0
# 4           5             6                      2.0         1.0          2.0
#
#    Deck  DesignofHouse  Division  TypeofFinancing  FinishedBasement  ...  \
# 0   1.0            1.0         1              1.0               2.0  ...
# 1   1.0            1.0         1              4.0               1.0  ...
# 2   2.0            1.0         1              1.0               2.0  ...
# 3   1.0            1.0         1              1.0               2.0  ...
# 4   2.0            1.0         1              1.0               2.0  ...
#
#    HalfBathrooms  SaleDate  Weight  PrimarySpaceHeatingFuel  SalesPrice  \
# 0            1.0    199904      53                      3.0    249900.0
# 1            0.0    199904      39                      1.0    139900.0
# 2            1.0    199903      58                      2.0    271900.0
# 3            1.0    199907      40                      2.0    320000.0
# 4            0.0    199812      31                      3.0    163000.0
#
#    SquareFootAreaofHouse  LotValue  SquareFootAreaofFinishedBasement  \
# 0                 2400.0   80000.0                               0.0
# 1                 1192.0   30000.0                             596.0
# 2                 2376.0   90000.0                               0.0
# 3                 2600.0   90000.0                               0.0
# 4                 1120.0   63700.0                               0.0
#
#    SquareFootAreaoftheLot  SaleYear
# 0                 52272.0      1999
# 1                  9000.0      1999
# 2                 40075.0      1999
# 3                 40075.0      1999
# 4                 87120.0      1998
#
# [5 rows x 33 columns]

# %%
df1 = dt[['SaleYear','SalesPrice']].copy()
dfplot = pd.DataFrame(df1.groupby(['SaleYear'])['SalesPrice'].agg('sum'))
dfplot = dfplot.reset_index()
dfplot
# Out:
#     SaleYear    SalesPrice
# 0       1996  8.855000e+05
# 1       1997  1.415860e+07
# 2       1998  6.508832e+08
# 3       1999  2.541101e+09
# 4       2000  2.964321e+09
# 5       2001  2.808159e+09
# 6       2002  3.096862e+09
# 7       2003  3.304880e+09
# 8       2004  3.724772e+09
# 9       2005  3.682032e+09
# 10      2006  2.720350e+09
# 11      2007  2.166643e+09
# 12      2008  1.411238e+09
# 13      2009  1.047286e+09
# 14      2010  1.043295e+09
# 15      2011  1.020045e+09
# 16      2012  1.209578e+09
# 17      2013  1.308559e+09
# 18      2014  1.268670e+09
# 19      2015  1.503265e+09
# 20      2016  1.591406e+09
# 21      2017  1.719018e+09
# 22      2018  1.228731e+09
# 23      2019  1.618230e+08

# %%
dfplot.plot.bar(x='SaleYear', y='SalesPrice', rot=90)
plt.title('Sum of Sale Values of Properties vs. Sale Year')
plt.ylabel('Sum Sales Value in 10^9')
plt.show()

# %%
df2 = pd.crosstab(index=dt['SaleYear'],columns="SalesPrice")
df2 = df2.reset_index()
df2.plot.bar(x='SaleYear', y='SalesPrice', rot=90)
plt.title('Counts of Sale of Properties vs. Sale Year')
plt.ylabel('Sum Sales Count in Year')
plt.show()

# %% [markdown]
# ##### As you can see in both figures above there is a major drop in values during the period of around 2008-2009. This is reasoned by the 2008 economic crisis

# %% [markdown]
# # 5) Detecting Outliers in Sales Price according to Boxplot Rules
# # (Need to be Revised)

# %%
df2['SalesPrice'].plot.box()
plt.show()

# %% [markdown]
# From the above boxplot, we notice that the 'Sales Price' variable has some outliers. According to the boxplot rule, outliers are data points that are out of the range [Q1 – 1.5IQR, Q3 + 1.5IQR]. Now, let's use the boxplot rule to detect outliers from the dataset.

# %%
# Calculate the first quantile
first_quantile = df2['SalesPrice'].quantile(0.25)

# Calculate the first quantile
third_quantile = df2['SalesPrice'].quantile(0.75)

# Calculate the interquantile range (IQR)
IQR = third_quantile - first_quantile

# %%
# Outliers below the boxplot
df2[df2['SalesPrice']<first_quantile-1.5*IQR]
# Out:
# Empty DataFrame
# Columns: [ConstructionMethod, SalesPrice]
# Index: []

# %%
# Outliers above the boxplot
df2[df2['SalesPrice']>first_quantile-1.5*IQR]
# Out:
#        ConstructionMethod  SalesPrice
# 0              Site_built    249900.0
# 1                 Modular    139900.0
# 2              Site_built    271900.0
# 3              Site_built    320000.0
# 4              Site_built    163000.0
# ...                   ...         ...
# 158465         Site_built   1220000.0
# 158466         Site_built    405000.0
# 158467         Site_built    699000.0
# 158468         Site_built    410000.0
# 158469         Site_built    445000.0
#
# [158470 rows x 2 columns]
